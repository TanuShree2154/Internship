# %%
#1) Practice print statement:
#  - with multiple object
print("Name:", "Tanu", "Age:", 19)
#  - with seperator 
print("A", "B", "C", sep="-")
# - with "ends" 
print("Loading", end="...")
print("Done")
# 2) Using input ask user to enter his/her name and output user name with a greeting message
name = input("Enter your name: ")
print("Hello "+ name )
# Out:
# Name: Tanu Age: 19
# A-B-C
# Loading...Done
# Hello tanu
