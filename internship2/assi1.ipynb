# %%
#1) Write a python program that takes in a student name, class. It should also take in five subject marks 
# of the students and find the total mark and percentage. Display a result in such a way that their name,
#  class,  and percentage are printed.

st_name = input("enter name of student:")
st_class = int(input("enter class of student:"))
s1_mark= int(input("enter marks of subject 1:"))
s2_mark= int(input("enter marks of subject 2:"))
s3_mark= int(input("enter marks of subject 3:"))
s4_mark= int(input("enter marks of subject 4:"))
s5_mark= int(input("enter marks of subject 5:"))
total_marks = s1_mark +s2_mark + s3_mark +s4_mark + s5_mark
percentage = (total_marks*100)/500
print(f"name of student:{st_name}")
print(f"class of student:{st_class}")
print(f"total marks: {total_marks}")
print(f"percentage:{percentage}%")
# Out:
# nameof student:tanu
# class of student:12
# total marks: 150
# percentage:30.0

# %%
#2) Input 2 strings concatinate them and store in another variable. then perform generally used string
#  methods on it like

#lower(), upper(), title(), swapcase(), capitalize(), casefold(), center(), count(), endswith(), find(), 
# isalnum(), isdigit(), isnumeric(), isspace(), replace()

str1 = input("enter string 1:")
str2 = input("enter string 2:")
str = str1 + str2
print (str)
print(f"lowercase: {str.lower()}")
print(f"uppercase: {str.upper()}")
print(f"title: {str.title()}")
print(f"swapcase: {str.swapcase()}")
print(f"capitalize: {str.capitalize()}")
print(f"casefold: {str.casefold()}")
print(f"center: {str.center(70)}")
print(f"count: {str.count('is')}")
print(f"endswith: {str.endswith("is")}")
print(f"find: {str.lower().find("python")}")
print(f"isalnum: {str.isalnum()}")
print(f"isdigit: {str.isdigit()}")
print(f"isnumeric: {str.isnumeric()}")
print(f"isspace: {str.isspace()}")
print(f"replace: {str.lower().replace('this','it')}")
# Out:
# This is Python
# lowercase: this is python
# uppercase: THIS IS PYTHON
# title: This Is Python
# swapcase: tHIS IS pYTHON
# capitalize: This is python
# casefold: this is python
# center:                             This is Python
# count: 2
# endswith: False
# find: 8
# isalnum: False
# isdigit: False
# isnumeric: False
# isspace: False
# replace: it is python

# %%
#4) Do practise of assignment operators

x = int(input("enter a number:"))
print(x)
x += 5
print(x)
x-=4
print(x)
x*=5
print(x)
x/=5
print(x)
x//=5
print(x)
x%=4
print(x)
x**=2
print(x)
# Out:
# 5
# 10
# 6
# 30
# 6.0
# 1.0
# 1.0
# 1.0

# %%
#5) In your last program where you find the total and percentage of a student's marks of 5 subject,
#  find the grade of the student using conditional statement. Eg. grade 'A' if percentage is greator
#  than or equals to 60, 'B' for  percentage is greator than or equals to 50 and less than 60,  'C'
#  for  percentage is greator than or equals to 40 and less than 50,  'D' for  percentage is greator
#  than or equals to 33 and less than 40, otherwise 'Fail'


st_name = input("enter name of student:")
st_class = int(input("enter class of student:"))
s1_mark= int(input("enter marks of subject 1:"))
s2_mark= int(input("enter marks of subject 2:"))
s3_mark= int(input("enter marks of subject 3:"))
s4_mark= int(input("enter marks of subject 4:"))
s5_mark= int(input("enter marks of subject 5:"))
total_marks = s1_mark +s2_mark + s3_mark +s4_mark + s5_mark
per = (total_marks*100)/500
print(f"name of student:{st_name}")
print(f"class of student:{st_class}")
print(f"total marks: {total_marks}")
print(f"percentage:{per}%")
if(per >= 60):
    print("grade A")
elif(per >=50):
    print("grade B")
elif(per >=40):
    print("grade C")
elif(per >= 33):
    print("grade D")
else:
    print("fail")
# Out:
# nameof student:tanu
# class of student:12
# total marks: 366
# percentage:73.2%
# grade A
